# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Aresh\Downloads\heart (1).csv')

# %%
df.head()

# %%
print(df.isnull().sum())
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# std      0.525860   22.905161    0.469794    1.161075    0.616226    1.022606
# min      0.000000   71.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000    0.000000
# 50%      1.000000  153.000000    0.000000    0.800000    1.000000    0.000000
# 75%      1.000000  166.000000    1.000000    1.600000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.200000    2.000000    4.000000
#
#              thal      target
# count  303.000000  303.000000
# mean     2.313531    0.544554
# std      0.612277    0.498835
# min      0.000000    0.000000
# 25%      2.000000    0.000000
# 50%      2.000000    1.000000
# 75%      3.000000    1.000000
# max      3.000000    1.000000

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score , f1_score ,classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
df_encoded = pd.get_dummies(df)

# %%
df_encoded.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='str')

# %%
X = df.drop('target', axis=1)
Y = df['target']

# %%
X_train, X_test , Y_train , Y_test = train_test_split(
    X,Y,test_size = 0.2 ,random_state = 42)
#split data

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

#scale features

# %%
#train model

models = {
    "Logistic Regression" : LogisticRegression(max_iter = 1000),
    "Decision Tree" : DecisionTreeClassifier(random_state =42),
    "Naive Bayes" : GaussianNB(),
    "KNN" : KNeighborsClassifier(n_neighbors = 5),
    "SVM" : SVC()
    
}

for name , model in models.items():
    model.fit(X_train , Y_train)
    Y_pred = model.predict(X_test)

    print(f"\n{name}")
    print("Accuracy:", accuracy_score(Y_test, Y_pred))
    print("F1 Score:", f1_score(Y_test, Y_pred))
    print(classification_report(Y_test, Y_pred))
# Out:
# Logistic Regression
# Accuracy: 0.8524590163934426
# F1 Score: 0.8571428571428571
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85        29
#            1       0.87      0.84      0.86        32
#
#     accuracy                           0.85        61
#    macro avg       0.85      0.85      0.85        61
# weighted avg       0.85      0.85      0.85        61
#
#
# Decision Tree
# Accuracy: 0.7540983606557377
# F1 Score: 0.7368421052631579
#               precision    recall  f1-score   support
#
#            0       0.69      0.86      0.77        29
#            1       0.84      0.66      0.74        32
#
#     accuracy                           0.75        61
#    macro avg       0.77      0.76      0.75        61
# weighted avg       0.77      0.75      0.75        61
#
#
# Naive Bayes
# Accuracy: 0.8688524590163934
# F1 Score: 0.8709677419354839
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        29
#            1       0.90      0.84      0.87        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
#
# KNN
# Accuracy: 0.9016393442622951
# F1 Score: 0.9032258064516129
#               precision    recall  f1-score   support
#
#            0       0.87      0.93      0.90        29
#            1       0.93      0.88      0.90        32
#
#     accuracy                           0.90        61
#    macro avg       0.90      0.90      0.90        61
# weighted avg       0.90      0.90      0.90        61
#
#
# SVM
# Accuracy: 0.8688524590163934
# F1 Score: 0.8709677419354839
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        29
#            1       0.90      0.84      0.87        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61

# %%
import joblib
best_model = KNeighborsClassifier(n_neighbors = 5)
best_model.fit(X_train ,  Y_train)
joblib.dump(best_model , "heart_model.apk")
joblib.dump(scaler , "scaler.pkl")
# Out:
# ['scaler.pkl']

# %%
# for findign the cross-validation accuracy across all models for better choice of deployment across multiple tested train/test splits

from sklearn.model_selection import cross_val_score

knn = KNeighborsClassifier(n_neighbors=5)

scores = cross_val_score(knn, X, y, cv=10)

print("Accuracy for each fold:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Accuracy for each fold: [0.70967742 0.67741935 0.5483871  0.63333333 0.63333333 0.56666667
#  0.76666667 0.7        0.53333333 0.76666667]
# Mean Accuracy: 0.6535483870967742

# %%
from sklearn.model_selection import cross_val_score

lr = LogisticRegression(max_iter = 1000)

scores = cross_val_score(lr, X, y, cv=10)

print("Accuracy for each fold:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Accuracy for each fold: [0.87096774 0.80645161 0.83870968 0.86666667 0.9        0.76666667
#  0.86666667 0.83333333 0.7        0.73333333]
# Mean Accuracy: 0.8182795698924732

# %%
from sklearn.model_selection import cross_val_score

GNB = GaussianNB()

scores = cross_val_score(GNB, X, y, cv=10)

print("Accuracy for each fold:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Accuracy for each fold: [0.80645161 0.80645161 0.87096774 0.9        0.8        0.73333333
#  0.9        0.8        0.73333333 0.7       ]
# Mean Accuracy: 0.8050537634408602

# %%
from sklearn.model_selection import cross_val_score

dct = DecisionTreeClassifier(random_state =42)

scores = cross_val_score(dct, X, y, cv=10)

print("Accuracy for each fold:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Accuracy for each fold: [0.80645161 0.83870968 0.87096774 0.83333333 0.8        0.73333333
#  0.7        0.76666667 0.7        0.7       ]
# Mean Accuracy: 0.7749462365591399

# %%
from sklearn.model_selection import cross_val_score

sv = SVC()
scores = cross_val_score(sv, X, y, cv=10)

print("Accuracy for each fold:", scores)
print("Mean Accuracy:", scores.mean())
# Out:
# Accuracy for each fold: [0.58064516 0.74193548 0.5483871  0.7        0.8        0.73333333
#  0.6        0.7        0.56666667 0.63333333]
# Mean Accuracy: 0.6604301075268817
